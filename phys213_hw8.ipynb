# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 1
# 思路
# 这个题一种是可逆热机（例如卡诺），是输出功的，就是用eta=Wout/Q=h这个式子
# 另一种是制冷或者制热，是输入功的, 用cop=Tc/Th-Tc=Qc/Winput


Tc=-18
Th=62
Win=800

#####################################以上是需要自己修改的数据


Tc=Tc+273.15
Th=Th+273.15
from sympy import *

Qc=S('ch')
cop1=Qc/Win

cop2=Tc/(Th-Tc)

q1=cop1-cop2
Qc=solve(q1)[0]
print('Qc',Qc)



Qh=Qc+Win
print('Qh',Qh)


# 但是我发现一个奇怪的事情，就是好像看作热机，似乎算出来结果是一样的
cop=Qc/Win
print('cop',cop)
# Out:
# [2551.49999999996]
# Qc 2551.50000000000
# Qh 3351.50000000000
# cop 3.18937500000000

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 思路
# W=integrate(p,(v,v1,v2))
from sympy import *
b=1.4e-28
n=3  #mol
V1=0.001# m**3
T=300 # K
V2=0.002# m**3


################################
Na=6.02e23

N=n*Na
k=1.38e-23# J/k
p1=N*k*T/(V1-N*b)
print(p1)


p2=N*k*T/(V2-N*b)
print(p2)


V=S('V')
p=N*k*T/(V-N*b)

W=integrate(p,(V,V1,V2))
print(W)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
m=82

###########################

T=373.15
p=101325
M=18 #g/mol
L=2260 #J/g
R=8.314 

Q=m*L
print(Q)

n=m/M

V=n*R*T/p

W=p*V
print(W)


dertaU=Q-W
print(dertaU)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 
# pv=NkT N是个数
# pv=n*R*T R=8.314
# pv=m*Rbar*T  Rbar=8.314/M
from sympy import *
V1=1e-3
rou=0.04 # kg/mol
p1=1e5
t=21
V2=3e-3



##############################

R=8.314
k=1.38e-23
T1=t+273.15

N_V=p1/k/T1
print('N_V',N_V)

# gamma=5/3
# T2=T1*(V1/V2)**(gamma-1)
# print(T2-273)

print('内能不变',T1-273.15)







p2=p1*V1/V2
print(p2)


n=p1*V1/R/T1
W=n*R*T1*ln(V2/V1)

print(W)
# Out:
# N_V 2.4634971312575907e+25
# 内能不变 21.0
# 33333.333333333336
# 109.861228866811
