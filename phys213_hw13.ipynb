# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 1


# 已知内能U=A*V*T**4
# cv=dU/dT
# cv=4*A*V*T**3

x=3
print('x',x)


# dU=TdS-PdV 但是这题没有V变化
# ds=dQ/T=dU/T=Cv/T*dT
# cv=4*A*V*T**3 
# S=4/3*A*V*T**3
y=3
print('y',y)

#亥姆霍兹自由能F=U-TS 
# U=A*V*T**4
# TS=4/3*A*V*T**4

U=11
F=-U/3
print(F)


# 吉布斯自由能 G=U+PV-TS
# 光子气体 压强P和能量密度u=U/V的关系是
# p=1/3*u=1/3*U/V
G=0
print(G)
# Out:
# x 3
# y 3
# -3.6666666666666665
# 0

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
rate=1.3
# FE的轨道半径是RE的1.3倍，假设两者都是均匀温度黑体，求这两个的温度之比

from sympy import *


print(sqrt(1/rate))



r=0.25

print(1)
Tnew_Tblack=(1-r)**(0.25)
print(Tnew_Tblack)



Tnew_Tblack=(1/(1-r))**(1/4)
print(Tnew_Tblack)
# Out:
# 0.877058019307029
# 1
# 0.9306048591020996
# 1.074569931823542

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3

T0=1.6e8
Uinitial=1


print(0)
Vi=1
Vf=1.01*Vi
dV=Vf-Vi
Wby=1/3*Uinitial/Vi*dV
print(Wby)
print(-Wby)


dT=-T0/3*0.01
print(dT)

print(1/3)
# Out:
# 0
# 0.003333333333333336
# -0.003333333333333336
# -533333.3333333334
# 0.3333333333333333
