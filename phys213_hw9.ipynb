# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
c=1.5
T1=273.15
T2=293.15

W=c*(T2*ln(T2/T1)-(T2-T1))

print(W)
T1=263.15
T2=283.15
W=c*(T2*ln(T2/T1)-(T2-T1))


print(W)
# Out:
# 1.07243215478255
# 1.11220236330209

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 2
# 思路
# 先找到平衡时刻到
from sympy import *
Va=S('Va')

na=1
nb=2
V=1
b=2e-4
# 压力平衡公式,其实就是sa+sb求导等于0

q1=na/(Va-b*na)-nb/(V-Va)
solve(q1)
# Out:
# [0.333466666666667]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
n=1.2
R=8.314
T=280
Va=2
Vb=3.5

dertaS_gas=n*R*ln((Va+Vb)/Va)
Wmax=dertaS_gas*T
print(Wmax)
# Out:
# 2825.91119317748

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 思路
# F=U-TS
# U=M*E 对于一个两状态系统 M 是处于高能状态的系统数，E是两个状态之间的能量差
# S=kb*ln(omega）
# omega=(N M)=N!/(N-M)!M!
# 这里的N是总粒子数，M是处于高能态的粒子数

from sympy import *

N=1e8
E=7e-21
T=300
M=4e7

print(E)
k=1.38e-23

d=ln(M)-ln(N-M)

# 这里没有想清楚为什么是正的
print(-k*d)


# F=M*E-k*T*(ln(M)-ln(N-M))
# 对M求导并令其等于0

M=S("M")

F=M*E-k*T*(ln(M)-ln(N-M))
q1=diff(F,M,1)
# print(q1)
print(solve(q1))


# print(N/2*(1+sqrt(1-4*k*T/N/E)))
# print(4*k*T/N/E)
# Out:
# 7e-21
# 5.59541849189266e-24
# [0.591428574926449, 99999999.4085714]

# %%
# 3

# %%
# 定义常量
N = 1e8
E = 7e-21
T = 300
M = 4e7

# 打印常量值
print("E =", E)
print("N =", N)
print("T =", T)
print("M =", M)

# 玻尔兹曼常数
k = 1.38e-23

# 计算 k * N / (M * (N - M))
k * N / (M * (N - M))
# Out:
# E = 7e-21
# N = 100000000.0
# T = 300
# M = 40000000.0
# 5.7500000000000005e-31
