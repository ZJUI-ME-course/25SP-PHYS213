# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# nc=N/2*exp(-derta/2/k/T)
from sympy import *
N=1e20
derta=1.424 # eV
k=8.617e-5 # eV/K
T=278.15
nc=N/2*exp(-derta/2/k/T)


print(nc)
# Out:
# 6277670.65897613
