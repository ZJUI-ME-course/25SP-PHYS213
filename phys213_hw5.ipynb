# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1
from math import *

q=3
n=3

result1 = comb(n+q-1, q)
print(result1)  # 输出：10


q=5
n=3 

result2 = comb(n+q-1, q)
print(result2)  # 输出：10

q=5
n=2

result3 = comb(n+q-1, q)
print(result3/result2)  # 输出：10


q=1
n=2

result4 = comb(n+q-1, q)
print(result4/result2)
# Out:
# 10
# 21
# 0.2857142857142857
# 0.09523809523809523

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2
from sympy import *



# 因为指数函数概率递减，所以0的时候概率最大，就是exp（-ne/k/T）

print(0)

e=1e-20
T=320 #K
k=1.38e-23


p2e_p0=exp(-2*e/k/T)
print(p2e_p0)


pEb=2*exp(-3)/(1*exp(-1)+2*exp(-3)+3*exp(-5))
print(pEb.evalf())
# Out:
# 0
# 0.0107916185400865
# 0.204184517717889

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3
# 波尔滋蔓分布式 
# Nup=C*exp(-miu*B/k/T)
# Edown-Eu=miu*B
# 通过解rate=exp(-2*miu*B/k/T)得到B

from sympy import *

rate=60e-2
T=24 # C
miu=9.3e-24 # J/Tesla
########################



k=1.38e-23 #J.K
T=T+273.15

Nup_Ndown_rate=rate/(1-rate)

print(Nup_Ndown_rate)


dertaE=k*T*ln(Nup_Ndown_rate)
print(dertaE)

B=k*T/miu/2*ln(Nup_Ndown_rate)
print(B)
# Out:
# 1.4999999999999998
# 1.66267860486591e-21
# 89.3913228422530

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 4
from sympy import *
k=8.617e-5 # ev/K
T=300


E0=0
E1=0.1# ev

e0=E0/k/T
e1=E1/k/T
print()

p0=exp(-e0)
p1=exp(-e1)


ptotal=p0+2*p1
p0=p0/ptotal
p1=2*p1/ptotal

print(p1)

print(1/3)

T=S('T')
e1=E1/k/T
p0=exp(-e0)
p1=exp(-e1)


# 注意这里有系数
q1=2*p1-p0
print(solve([q1],[T])[0][0])

print(0)
# Out:
# 0.0401106886658869
# 0.3333333333333333
# 1674.24282335960
# 0
