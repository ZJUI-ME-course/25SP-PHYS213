# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 1

dh=6e-22
ds=5e-24

Na=6.022e23

dh_mol=dh*Na
print(dh_mol)


# 在熔点，固相液相平衡，此时dG=0,dG=dH-TdS

T=dh/ds 
print(T)
# Out:
# 361.32
# 120.0

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
m=10e3 #g
T=373.15
p=101325
Lv=2230 #J/g
M=18 #g/mol
Q=1e3
R=8.314 # J/mol/K

m1=Q/Lv
print(m1)

# dG=dH-TdS=Q-T*Q/T
print(0)

# 这里还不是很理解为什么这些式子是对的
dS=Q/T
print(dS)
print(Q)


V_vapor=m1/M*R*T/p
V_water=m1*1e-6
dV=V_vapor-V_water
print(dV)

W=p*dV
dU=Q-W
print(dU)
# Out:
# 0.4484304932735426
# 0
# 2.6798874447273215
# 1000.0
# 0.0007623319000325901
# 922.7567202291978

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 3

L=2.256e6 # J/kg
M=0.018 #kg/mol
p=101300 #pa
T=373.15 # K
R=8.314 # J/mol/K
Lmol=L*M
rate=Lmol*p/R/T**2


dp=rate*-1
print(dp)
# Out:
# -3553.400291961018
