# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2

from sympy import *

print(0)

n=1
T=300
p=1e6
R=8.314 # J/mol/k

V=n*R*T/p
print(V)


# 现在不理解为什么取N=1

Na=6.022e23

N=Na*n
b=9e-29


T=300
p=1e6
k=1.38e-23



# 因为s-N*k*ln(V-Nb)+其他与V无关的项，所以ds/dV=(Nk)/(V-Nb)
# 因为G=U+p*V-T*S
# 平衡条件 dG/dV=0，
# 得到p=T*NK/(V-Nb)
# 进而得到p=T*(Nk)/(V-Nb)


V=b+N*k*T/p
print(V)
# Out:
# 0
# 0.0024942
# 0.0024931080000000004

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# 3
# d(PV)=p2*v2-p1*v1=nRT-nRT=0
p1=4e5
p2=2e5
R=8.314
n=1
T=300
# G=U-TS+PV
# dU=0
# ds=n*R*ln(V2/V1)=n*R*ln(p1/p2)
dS=n*R*ln(p1/p2)
dG=0-T*dS+0
print(dG)

# 对于纯物质 G=Na*miu
# miuf-miui=dG
Na=6.022e23
dmiu=dG/Na
print(dmiu)


b=2e-28
# S=Nk*ln(V-Nb)+f(T,N)



k=1.38e-23
T=300

dG=Na*k*T*ln(p2/p1)+Na*b*(p2-p1)

print(dG)

dmiu=dG/Na
print(dmiu)
# Out:
# -1728.84769775262
# -2.87088624668319e-21
# -1752.17878103144
# -2.90962932751817e-21

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 4
print(3740.6)
# Out:
# 3740.6
