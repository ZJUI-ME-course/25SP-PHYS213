# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Pv=nRT

print(0)
n=1
p=1e6
T=300

R=8.314
v=n*R*T/p

print(v)
# Out:
# 0.0024942

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 3

# %% [markdown]
# ![image.png](attachment:image.png)
