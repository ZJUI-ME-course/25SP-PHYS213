# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# dertaU=Uf-Ui=Ki-Kf
# 不可逆

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 等温dertaS=Qin/T
# 液体水升温的cp=cv
# dertaS=integrate(m*cv/t,(T,Ti,Tf))=m*cv*ln(Tf/Ti)
from sympy import *
m=500e-3 # kg
Ti=273.15
Tf=293.15

Cice=333.5e3 # J/kg
Cliquid=4184  #J/kg/K

# 这里Cice是融化热，所以不需要做差
Q1=m*(Cice)
dertaS1=Q1/Ti
print('dertaS1',dertaS1)


dertaS2=m*Cliquid*ln(Tf/Ti)
print('dertaS2',dertaS2)

Q2=Cliquid*m*(Tf-Ti)
print('Qtotal',Q2+Q1)
# Out:
# dertaS1 610.4704374885595
# dertaS2 147.827683365297
# Qtotal 208590.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 这个图现在不理解，等着大佬教学

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 
# P=P0*exp(-m*g(h/k/T))
m=4.65e-26

##################################
g=9.81
k=1.38e-23
T=250

dertah=1000-500
p=exp(-m*g*(dertah/k/T))
print('r',p)


print('increse')
# Out:
# r 0.936027081622984
# increse

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

# 定义常量
k = 1.38e-23
T = 250
E0 = 0
E1 = 1.6e-21
E2 = 1.6e-21

# 计算 beta
beta = 1 / (k * T)
from math import exp as e
# 计算配分函数 Z
Z =e(-beta * E0) + e(-beta * E1) + e(-beta * E2)
Ebar=1/Z*(E0*e(-E0*beta)+E1*e(-E1*beta)+E2*e(-E2*beta))
print(Ebar)
# Out:
# 8.913514405023444e-22

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 对外是 W=n*R*T*ln(vf/vi)
# 问的是对内的 W=-n*R*T*ln(vf/vi)

from sympy import *
R=8.31 # J/mol/K
n=2 # mol
T=290 # K
vf=1
vi=2

W=-n*R*T*ln(vf/vi)

print(W)
# Out:
# 3340.83078086282

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m=500 # g

M=107 #g/mol
Q=300 #J
Cm=3*8.31 # J/mol/K

n=m/M
# Q=n*Cm*dertaT
dertaT=Q/Cm/n 
print(dertaT)
# Out:
# 2.575210589651023

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tf=250
ti=290
###################

# dertaS=integrate(Cv/T,(T,ti,tf))
T=S('T')

alpha =0.8 # J/K/K
Cv=alpha*T

dertaS=integrate(Cv/T,(T,ti,tf))

print(dertaS)
# Out:
# -32.0000000000000

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 思路
# c代表copper h代表helium

# 高温物体释放的热量等于低温物体吸收的热量
# mc*Cc*dertaT1=nh*Ch_mol*dertaT2

mc=0.3# kg
nh=1.5 
Th=120
Tc=20


#############################

Cc=386 # J/kg/K
Ch_mol=12.5 # J/mol/K

Th=Th+273.15
Tc=Tc+273.15

Tf=S('Tf')

q1=mc*Cc*(Tf-Tc)-nh*Ch_mol*(Th-Tf)
solve(q1)
# Out:
# [307.085340022297]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *

# p=exp(-E2/kt)/(exp(-E1/kt)+exp(-E2/kt))同除以分子
# p=1//(exp(-E1+E2/kt)+1)
dertaE=1.1e-21

T=247
k=1.38e-23

p=1/(exp(dertaE/k/T)+1)

print(p)
# Out:
# 0.420014678165512
