# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
U=12



# 12个能量子 3个谐振子
# 12+3-1取3-1
omega=14*13/2

E1=U/3

print(E1)


# 3个能量子 分配给两个谐振子
print(4/omega)


# KT=0.5e E=
# Out:
# 4.0
# 0.04395604395604396

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
7/2*8.314*0.37*15
# Out:
# 161.49945
